# %% [markdown]
# **import package**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
import seaborn as sns

# %% [markdown]
# **read the data**

# %%
import pandas as pd
Visa_df = pd.read_csv('Visadataset.csv')
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **tail**
# - tail prints/ gives the last 5 rows of the data

# %%
#
Visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# **head**
# - head prints/ gives the first 5 rows of the data

# %%
Visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# **shape**
# - it gives the shape of the dataframe
#
# - which is in the form of matrics

# %%
Visa_df.shape

# dtaframe is the matrix kinde of representation
#it has rows and columns
# rows 1599 columns 12
# the ans in touple
# Out:
# (25480, 12)

# %%
print("number odf rows ",Visa_df.shape[0])
print("number of columns",Visa_df.shape[1])
# Out:
# number odf rows  25480
# number of columns 12

# %% [markdown]
# **size**

# %% [markdown]
# it is the multiplication of rows and columns
#
# we have 5 and 4 rows and column so that 5X4 =20

# %%
Visa_df.size
# Out:
# 305760

# %% [markdown]
# **column**

# %%
Visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(Visa_df.columns)
# Out:
# 12

# %%
type(Visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# **type cast in to list**

# %%
list(Visa_df.columns)
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# **dtypes**
#
# - it gives the datatypes of all rows
#
# - object means categorical data types
#
# - the data types given in series types

# %%
Visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dtypes = dict(Visa_df.dtypes)
dtypes

# concatinated in dictionary from touple
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
type(Visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task-1**
#
# **Extract categorical columns-numerical columns seperately**
#
# - Convert series type to dictionary
#
# - so that it will give key-value pair
#
# - iterate using for loop
#
# - apply the condition on value equal to object then extract corrosponding key

# %%
dtypes=dict(Visa_df.dtypes)
dtypes                            # converted all columns in dictionary with key of column name and datatypes are values
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
dtypes=dict(Visa_df.dtypes)
cat_list=[]
for key,value in dtypes.items():
    if value=='object':
        cat_list.append(value)

# %%
# dtypes=dict(Visa_df.dtypes)
# cat_list=[key for key,value in dtypes.items() if value=='object']
# num_list=[key for key,value in dtypes.items() if value!='object']  
# by using the list comprehension

# %%
cat_list
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# df1
pd.DataFrame(cat_list,columns=['Object type'])
# Out:
#              Object type
# 0                case_id
# 1              continent
# 2  education_of_employee
# 3     has_job_experience
# 4  requires_job_training
# 5   region_of_employment
# 6           unit_of_wage
# 7     full_time_position
# 8            case_status

# %%
pd.DataFrame(num_list,columns=['Numerical type'])
# Out:
#     Numerical type
# 0  no_of_employees
# 1      yr_of_estab
# 2  prevailing_wage

# %%
Visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# $Method-1$
#
# - any series can convert into dictionary
#
# - any dictionary  can make in to list
#
# - any list can make into dataframe

# %%
dtypes1=dict(Visa_df.dtypes)
keys=dtypes1.keys()
values=dtypes1.values()
dtype_df=pd.DataFrame(zip(keys,values),columns=['Column','Data type'])
dtype_df
# Out:
#                    Column Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# $Method-2$
#
# - Every series have to method
#
# - one is key
#
# - second is values

# %%
keys = Visa_df.dtypes.keys()

# %%
values=Visa_df.dtypes.values

# %%
pd.DataFrame(zip(keys,values))
# Out:
#                         0        1
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %% [markdown]
# **Select dtypes**
#
# - it will give the catgorical column dataframe

# %%
Visa_df.select_dtypes(include='object')

cat_col=Visa_df.select_dtypes(include='object').columns
num_col=Visa_df.select_dtypes(exclude='object').columns
cat_col,num_col
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %% [markdown]
# **isnull**
#
# - isnull means we are asking a qn to the computer
#
# - if that perticular file has value or do not have value
#
# - if value present represent as False
#
# - if value is not present is true

# %%
Visa_df.isnull()

# it will give column wise null value
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
Visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **info**

# %%
Visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# **take**
#
# - we know that head will give top 5
#
# - tail will give last 5 values
#
# - but what if we want specific rows or specific columns
#
# - then we can use **take** method
#
# - take mathod take A list of values that represent index
#
# - by default axis= 0 which represent rows
#
# - if we provide axis = 1 which represents columns

# %%
Visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
Visa_df.take([100,200,300],axis=1)
# error

# %%
Visa_df.take([5,8,10],axis=1)
# Out:
#        no_of_employees  prevailing_wage full_time_position
# 0                14513         592.2029                  Y
# 1                 2412       83425.6500                  Y
# 2                44444      122996.8600                  Y
# 3                   98       83434.0300                  Y
# 4                 1082      149907.3900                  Y
# ...                ...              ...                ...
# 25475             2601       77092.5700                  Y
# 25476             3274      279174.7900                  Y
# 25477             1121      146298.8500                  N
# 25478             1918       86154.7700                  Y
# 25479             3195       70876.9100                  Y
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100:105])
#error
# Out:
#   Cell In[77], line 1
#     visa_df.take([100:105])
#                      ^
# SyntaxError: invalid syntax

# %%
Visa_df.take([5,8,10],axis=1).take([100,200,300],axis=0)
# Out:
#      no_of_employees  prevailing_wage full_time_position
# 100             2227         28243.79                  Y
# 200             3282         74441.11                  Y
# 300             3268        101371.21                  Y

# %% [markdown]
# #misceleneous

# %%
###################################### 29-08-2023 #################################

# %%
# whenever you open a notebook freshly
#make sure
# import the packajes 
# and read the data

# langchain genai

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seabern as sns

# %%
import pandas as pd
visa_df=pd.read_csv('Visadataset.csv')
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
#missing

# %%
take has two drawback 

function or method has(), but indexing has []

# %%
visa_df.iloc

# %%
visa_df.take
# Out:
# <bound method NDFrame.take of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# visa_df.iloc[<rows>,<columns>]

# rows we can do slice

# columns we can also slice

# visa_df.iloc[start:step:step,start:step:step]

# %%
visa_df.iloc[100:105,5:8]
# Out:
#      no_of_employees  yr_of_estab region_of_employment
# 100             2227         2007            Northeast
# 101              334         2007              Midwest
# 102              224         2008              Midwest
# 103              367         1982                 West
# 104              306         2003            Northeast

# %%
visa_df.iloc[[100,200,300],[5,7,9]]
# Out:
#      no_of_employees region_of_employment unit_of_wage
# 100             2227            Northeast         Year
# 200             3282                 West         Year
# 300             3268              Midwest         Year

# %%
visa_df.iloc[100:105,5:8]
visa_df.iloc[100:103]# 100 and 200 all the columns
visa_df.iloc[[100,200,300]] # 100,200,300 row and all the columns
visa_df.iloc[[100,200,300],[5,7,9]] # 5,7,9 columns with rows 100,200,300,

# one row with all columns
visa_df.iloc[:,1] # one column all the rows seriestype
visa_df.iloc[:,[1]]# one column all the rows dataframe type

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.iloc[:,]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **loc**
# - iloc and loc both are trying to retrive rows and columns
#
# - but for columns iloc expect index
#
# - loc expect direct column names

# %%
visa_df.loc[:,['winequality_red.csv']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 visa_df.loc[:,['winequality_red.csv']]
#
# File ~\Pankaj Anaconda\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\Pankaj Anaconda\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %% [markdown]
# **multipal values means aways think about list**
#
# **any parameter says index or array means, it is expecting a list of values**
#
# **the index values can represent as list, numpy
